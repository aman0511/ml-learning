# %%
! pip install opencv-python
# Out:
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import cv2

# %%
image_path='../data/dog.jpg'
image = cv2.imread(image_path)

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
image.shape
# Out:
# (340, 453, 3)

# %%
image
# Out:
# array([[[  8,  62,  57],
#         [  8,  62,  57],
#         [  8,  62,  57],
#         ...,
#         [ 79, 147, 140],
#         [ 79, 147, 140],
#         [ 79, 147, 140]],
#
#        [[  6,  60,  55],
#         [  6,  60,  55],
#         [  6,  60,  55],
#         ...,
#         [ 79, 147, 140],
#         [ 79, 147, 140],
#         [ 79, 147, 140]],
#
#        [[  6,  58,  51],
#         [  6,  58,  51],
#         [  6,  57,  53],
#         ...,
#         [ 79, 147, 140],
#         [ 79, 147, 140],
#         [ 79, 147, 140]],
#
#        ...,
#        [[ 12,  62,  58],
#         [ 11,  61,  57],
#         [ 12,  59,  56],
#         ...,
#         [176, 204, 234],
#         [172, 200, 230],
#         [168, 196, 227]],
#
#        [[ 13,  63,  59],
#         [ 11,  61,  57],
#         [ 12,  59,  56],
#         ...,
#         [175, 203, 233],
#         [173, 201, 231],
#         [170, 198, 229]],
#
#        [[ 13,  63,  59],
#         [ 12,  62,  58],
#         [ 13,  60,  57],
# ...

# %%
image[0][0]
# Out:
# array([ 8, 62, 57], dtype=uint8)

# %%
size = (32,32)
resize_image_feature_vector = cv2.resize(image, size)
plt.imshow(resize_image_feature_vector)

# %%
resize_image_feature_vector.flatten()
# Out:
# array([  6,  56,  52, ..., 177, 205, 231], dtype=uint8)

# %%
image_grayscale = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (340, 453)

# %%
image_grayscale
# Out:
# array([[ 54,  54,  54, ..., 137, 137, 137],
#        [ 52,  52,  52, ..., 137, 137, 137],
#        [ 50,  50,  50, ..., 137, 137, 137],
#        ...,
#        [ 55,  54,  53, ..., 210, 206, 202],
#        [ 56,  54,  53, ..., 209, 207, 204],
#        [ 56,  55,  54, ..., 208, 207, 205]], dtype=uint8)

# %%
import numpy as np
expanded_image_grayscale = np.expand_dims(image_grayscale, axis=2)
expanded_image_grayscale.shape
# Out:
# (340, 453, 1)

# %%
expanded_image_grayscale
# Out:
# array([[[ 54],
#         [ 54],
#         [ 54],
#         ...,
#         [137],
#         [137],
#         [137]],
#
#        [[ 52],
#         [ 52],
#         [ 52],
#         ...,
#         [137],
#         [137],
#         [137]],
#
#        [[ 50],
#         [ 50],
#         [ 50],
#         ...,
#         [137],
#         [137],
#         [137]],
#
#        ...,
#        [[ 55],
#         [ 54],
#         [ 53],
#         ...,
#         [210],
#         [206],
#         [202]],
#
#        [[ 56],
#         [ 54],
#         [ 53],
#         ...,
#         [209],
#         [207],
#         [204]],
#
#        [[ 56],
#         [ 55],
#         [ 54],
#         ...,
#         [208],
#         [207],
#         [205]]], dtype=uint8)
